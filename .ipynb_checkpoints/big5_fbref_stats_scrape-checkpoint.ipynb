# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from bs4 import BeautifulSoup
import requests
from itertools import chain
from tqdm import tqdm_notebook as tqdm
import itertools

# %%
STANDARD_STATS_URL = "https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats"
DEFENSE_STATS_URL = "https://fbref.com/en/comps/Big5/defense/players/Big-5-European-Leagues-Stats"
GCA_STATS_URL = "https://fbref.com/en/comps/Big5/gca/players/Big-5-European-Leagues-Stats"
MISC_STATS_URL = "https://fbref.com/en/comps/Big5/misc/players/Big-5-European-Leagues-Stats"
SHOOTING_STATS_URL = "https://fbref.com/en/comps/Big5/shooting/players/Big-5-European-Leagues-Stats"
PASSING_STATS_URL = "https://fbref.com/en/comps/Big5/passing/players/Big-5-European-Leagues-Stats"

# %%
def append_names(feature_list, head_tuple):
    start = 0
    end = 0
    for head in head_tuple:
        end = end + int(head[1])
        if head[0] != '':
            feature_list[start:end] = [head[0]+"_"+x for x in feature_list[start:end]]
        start = end
    return feature_list

# %%
def parse_page(URL):
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find('table', id="stats_standard")
    features = [col.attrs["data-stat"] for col in table.find('thead').findAll('tr')[1].findAll('th')]
    features.remove("ranker")
    features.remove("matches")
    header_name = [(col.attrs["data-stat"], col.attrs["colspan"]) for col in table.find('thead').findAll('tr')[0].findAll('th') if "data-stat" in col.attrs]
    features = append_names(features, header_name)
    player_table = table.find('tbody')
    #Parse player_table
    pre_df_player = []
    rows_player = player_table.find_all('tr')
    for row in tqdm(rows_player):
        if(row.find('th',{"scope":"row"}) != None):
        '''
        
            for f in features:
                cell = row.find("td",{"data-stat": f})
                if cell is not None:
                    a = cell.text.strip().encode()
                    text=a.decode("utf-8")
                    if f in pre_df_player:
                        pre_df_player[f].append(text)
                    else:
                        pre_df_player[f] = [text]
                else:
                    print(f"couldn't get stat for {f}")
        '''
    df_player = pd.DataFrame.from_dict(pre_df_player)
    return df_player

# %%
big5_standard_df = parse_page(STANDARD_STATS_URL)
# Out:
# /home/mancunian92/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=2820.0), HTML(value='')))
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# ...
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# couldn't get stat for header_performance_assists
# couldn't get stat for header_performance_pens_made
# couldn't get stat for header_performance_pens_att
# couldn't get stat for header_performance_cards_yellow
# couldn't get stat for header_performance_cards_red
# couldn't get stat for header_performance_goals_per90
# couldn't get stat for header_per90_assists_per90
# couldn't get stat for header_per90_goals_assists_per90
# couldn't get stat for header_per90_goals_pens_per90
# couldn't get stat for header_per90_goals_assists_pens_per90
# couldn't get stat for header_per90_xg
# couldn't get stat for header_expected_npxg
# couldn't get stat for header_expected_xa
# couldn't get stat for header_expected_xg_per90
# couldn't get stat for header_per90_xa_per90
# couldn't get stat for header_per90_xg_xa_per90
# couldn't get stat for header_per90_npxg_per90
# couldn't get stat for header_per90_npxg_xa_per90
# couldn't get stat for header_playing_games_starts
# couldn't get stat for header_playing_minutes
# couldn't get stat for header_playing_goals
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-e13a06d1f046> in <module>()
# ----> 1 big5_standard_df = parse_page(STANDARD_STATS_URL)
#
# <ipython-input-86-03ffc495664d> in parse_page(URL)
#      16
#      17             for f in features:
# ---> 18                 cell = row.find("td",{"data-stat": f})
#      19                 if cell is not None:
#      20                     a = cell.text.strip().encode()
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in find(self, name, attrs, recursive, text, **kwargs)
#    1290         criteria."""
#    1291         r = None
# -> 1292         l = self.find_all(name, attrs, recursive, text, 1, **kwargs)
#    1293         if l:
#    1294             r = l[0]
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    1653             markup_attrs = markup
#    1654         call_function_with_tag_data = (
# -> 1655             isinstance(self.name, collections.Callable)
#    1656             and not isinstance(markup_name, Tag))
#    1657
#
# ~/anaconda3/lib/python3.6/abc.py in __instancecheck__(cls, instance)
#     188             if (cls._abc_negative_cache_version ==
#     189                 ABCMeta._abc_invalidation_counter and
# --> 190                 subclass in cls._abc_negative_cache):
#     191                 return False
#     192             # Fall back to the subclass check.
#
# KeyboardInterrupt:

# %%
big5_standard_df.to_csv("./data/big5_standard_stats.csv", index=False)

# %%
{x for x in a}
# Out:
# {'age',
#  'assists',
#  'assists_per90',
#  'birth_year',
#  'cards_red',
#  'cards_yellow',
#  'comp_level',
#  'games',
#  'games_starts',
#  'goals',
#  'goals_assists_pens_per90',
#  'goals_assists_per90',
#  'goals_pens_per90',
#  'goals_per90',
#  'matches',
#  'minutes',
#  'nationality',
#  'npxg',
#  'npxg_per90',
#  'npxg_xa_per90',
#  'pens_att',
#  'pens_made',
#  'player',
#  'position',
#  'ranker',
#  'squad',
#  'xa',
#  'xa_per90',
#  'xg',
#  'xg_per90',
#  'xg_xa_per90'}
